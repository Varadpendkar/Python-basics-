# %% [markdown]
# # Introduction to Opencv and Image processing

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy  as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread(r'/Users/varadpendkar/Downloads/horse_image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (2334, 3502, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[29, 17, 15],
#         [29, 17, 15],
#         [29, 17, 15],
#         ...,
#         [35, 38, 23],
#         [31, 34, 19],
#         [27, 30, 14]],
#
#        [[29, 17, 15],
#         [29, 17, 15],
#         [29, 17, 15],
#         ...,
#         [36, 39, 24],
#         [34, 37, 22],
#         [33, 36, 20]],
#
#        [[29, 17, 15],
#         [29, 17, 15],
#         [29, 17, 15],
#         ...,
#         [38, 41, 26],
#         [37, 40, 25],
#         [37, 40, 24]],
#
#        ...,
#
#        [[44, 50, 49],
#         [33, 41, 40],
#         [29, 34, 35],
#         ...,
#         [29, 30, 14],
#         [25, 25, 13],
#         [23, 23, 11]],
#
#        [[44, 50, 45],
#         [36, 43, 38],
#         [30, 35, 33],
#         ...,
#         [25, 25, 11],
#         [24, 24, 12],
#         [27, 26, 16]],
#
#        [[33, 40, 33],
#         [33, 40, 33],
#         [32, 38, 33],
#         ...,
#         [26, 26, 12],
#         [27, 26, 16],
# ...

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img.shape
# Out:
# (2334, 3502, 3)
